# %%
import joblib
import numpy as np
import pandas as pd
import seaborn as sns 
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

# %%
! pip install huggingface_hub

# %%
df_1 = pd.read_csv("hf://datasets/maharshipandya/spotify-tracks-dataset/dataset.csv")
df_1.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
#  16  liveness          114000 non-null  float64
#  17  valence           114000 non-null  float64
#  18  tempo             114000 non-null  float64
#  19  time_signature    114000 non-null  int64
#  20  track_genre       114000 non-null  object
# dtypes: bool(1), float64(9), int64(6), object(5)
# memory usage: 17.5+ MB

# %%
df_1.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df_2 = pd.read_csv("data/SpotifyAudioFeaturesApril2019.csv")
df_2.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# 2       138913   0.723             0.000    9    0.0824    -5.890     0
# 3       125381   0.579             0.912    5    0.0994   -12.118     0
# 4       124016   0.792             0.878    7    0.0332   -10.277     1
#
#    speechiness    tempo  time_signature  valence  popularity
# 0       0.4090  203.927               4    0.118          15
# 1       0.4570  159.009               4    0.371           0
# 2       0.0454  114.966               4    0.382          56
# 3       0.0701  123.003               4    0.641           0
# 4       0.0661  120.047               4    0.928           0

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130663 entries, 0 to 130662
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artist_name       130663 non-null  object
#  1   track_id          130663 non-null  object
#  2   track_name        130662 non-null  object
#  3   acousticness      130663 non-null  float64
#  4   danceability      130663 non-null  float64
#  5   duration_ms       130663 non-null  int64
#  6   energy            130663 non-null  float64
#  7   instrumentalness  130663 non-null  float64
#  8   key               130663 non-null  int64
#  9   liveness          130663 non-null  float64
#  10  loudness          130663 non-null  float64
#  11  mode              130663 non-null  int64
#  12  speechiness       130663 non-null  float64
#  13  tempo             130663 non-null  float64
#  14  time_signature    130663 non-null  int64
#  15  valence           130663 non-null  float64
#  16  popularity        130663 non-null  int64
# dtypes: float64(9), int64(5), object(3)
# memory usage: 16.9+ MB

# %%
df_3 = pd.read_csv("data/SpotifyAudioFeaturesNov2018.csv")
df_3.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# 2       138913   0.723             0.000    9    0.0824    -5.890     0
# 3       125381   0.579             0.912    5    0.0994   -12.118     0
# 4       124016   0.792             0.878    7    0.0332   -10.277     1
#
#    speechiness    tempo  time_signature  valence  popularity
# 0       0.4090  203.927               4    0.118          44
# 1       0.4570  159.009               4    0.371          10
# 2       0.0454  114.966               4    0.382          63
# 3       0.0701  123.003               4    0.641           9
# 4       0.0661  120.047               4    0.928           8

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116372 entries, 0 to 116371
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artist_name       116372 non-null  object
#  1   track_id          116372 non-null  object
#  2   track_name        116371 non-null  object
#  3   acousticness      116372 non-null  float64
#  4   danceability      116372 non-null  float64
#  5   duration_ms       116372 non-null  int64
#  6   energy            116372 non-null  float64
#  7   instrumentalness  116372 non-null  float64
#  8   key               116372 non-null  int64
#  9   liveness          116372 non-null  float64
#  10  loudness          116372 non-null  float64
#  11  mode              116372 non-null  int64
#  12  speechiness       116372 non-null  float64
#  13  tempo             116372 non-null  float64
#  14  time_signature    116372 non-null  int64
#  15  valence           116372 non-null  float64
#  16  popularity        116372 non-null  int64
# dtypes: float64(9), int64(5), object(3)
# memory usage: 15.1+ MB

# %%
df_4 = pd.read_csv("data/train.csv")
df_4.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
#  16  liveness          114000 non-null  float64
#  17  valence           114000 non-null  float64
#  18  tempo             114000 non-null  float64
#  19  time_signature    114000 non-null  int64
#  20  track_genre       114000 non-null  object
# dtypes: bool(1), float64(9), int64(6), object(5)
# memory usage: 17.5+ MB

# %%
df_1.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
df_2.columns
# Out:
# Index(['artist_name', 'track_id', 'track_name', 'acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'popularity'],
#       dtype='object')

# %%
df_3.columns
# Out:
# Index(['artist_name', 'track_id', 'track_name', 'acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'popularity'],
#       dtype='object')

# %%
df_4.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
set(df_1.columns)|set(df_2.columns)|set(df_3.columns)|set(df_4.columns) #set union gives common and unique columns from each dataset
# Out:
# {'Unnamed: 0',
#  'acousticness',
#  'album_name',
#  'artist_name',
#  'artists',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'explicit',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'mode',
#  'popularity',
#  'speechiness',
#  'tempo',
#  'time_signature',
#  'track_genre',
#  'track_id',
#  'track_name',
#  'valence'}

# %%
df_1.rename(columns={'artists': 'artist_name'}, inplace=True)
df_4.rename(columns={'artists': 'artist_name'}, inplace=True)

# %%
set(df_1.columns)|set(df_2.columns)|set(df_3.columns)|set(df_4.columns) #set union gives common and unique columns from each dataset
# Out:
# {'Unnamed: 0',
#  'acousticness',
#  'album_name',
#  'artist_name',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'explicit',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'mode',
#  'popularity',
#  'speechiness',
#  'tempo',
#  'time_signature',
#  'track_genre',
#  'track_id',
#  'track_name',
#  'valence'}

# %%
set(df_1.columns) & set(df_2.columns) & set(df_3.columns) & set(df_4.columns) #set intersection gives common from all datasets
# Out:
# {'acousticness',
#  'artist_name',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'mode',
#  'popularity',
#  'speechiness',
#  'tempo',
#  'time_signature',
#  'track_id',
#  'track_name',
#  'valence'}

# %%
import pandas as pd

def merge_music_datasets(df1, df2, df3, df4):
    common_columns = [
        'track_id', 'artist_name', 'track_name', 'album_name', 
        'popularity', 'track_genre', 'duration_ms', 'acousticness',
        'danceability', 'energy', 'key', 'loudness', 'mode',
        'speechiness', 'instrumentalness', 'liveness', 'tempo',
        'time_signature'
    ]

    def process_df(df):
        for col in common_columns:
            if col not in df.columns:
                df[col] = None
        
        df = df[common_columns]
        
        numeric_cols = {
            'int64': ['duration_ms', 'key', 'mode', 'time_signature', 'popularity'],
            'float64': ['acousticness', 'danceability', 'energy', 'instrumentalness',
                       'liveness', 'loudness', 'speechiness', 'tempo']
        }
        
        for dtype, cols in numeric_cols.items():
            for col in cols:
                if col in df.columns:
                    df[col] = pd.to_numeric(df[col], errors='coerce').astype(dtype)
        
        return df
    

    dfs_cleaned = [process_df(df) for df in [df1, df2, df3, df4]]
    merged_df = pd.concat(dfs_cleaned, ignore_index=True)
    merged_df = merged_df.drop_duplicates(subset='track_id', keep='first')
    
    return merged_df

merged_df = merge_music_datasets(df_1, df_2, df_3, df_4)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
merged_df.head()
# Out:
#                  track_id             artist_name                  track_name  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino                      Comedy
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward            Ghost - Acoustic
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN              To Begin Again
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis  Can't Help Falling In Love
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet                     Hold On
#
#                                           album_name  popularity track_genre  \
# 0                                             Comedy          73    acoustic
# 1                                   Ghost (Acoustic)          55    acoustic
# 2                                     To Begin Again          57    acoustic
# 3  Crazy Rich Asians (Original Motion Picture Sou...          71    acoustic
# 4                                            Hold On          82    acoustic
#
#    duration_ms  acousticness  danceability  energy  key  loudness  mode  \
# 0       230666        0.0322         0.676  0.4610    1    -6.746     0
# 1       149610        0.9240         0.420  0.1660    1   -17.235     1
# 2       210826        0.2100         0.438  0.3590    0    -9.734     1
# 3       201933        0.9050         0.266  0.0596    0   -18.515     1
# 4       198853        0.4690         0.618  0.4430    2    -9.681     1
#
#    speechiness  instrumentalness  liveness    tempo  time_signature
# 0       0.1430          0.000001    0.3580   87.917               4
# 1       0.0763          0.000006    0.1010   77.489               4
# 2       0.0557          0.000000    0.1170   76.332               4
# 3       0.0363          0.000071    0.1320  181.740               3
# 4       0.0526          0.000000    0.0829  119.949               4

# %%
merged_df.isnull().sum()
# Out:
# track_id                 0
# artist_name              1
# track_name               2
# album_name          129900
# popularity               0
# track_genre         129899
# duration_ms              0
# acousticness             0
# danceability             0
# energy                   0
# key                      0
# loudness                 0
# mode                     0
# speechiness              0
# instrumentalness         0
# liveness                 0
# tempo                    0
# time_signature           0
# dtype: int64

# %%
def create_features(df):
    df_features = df.copy()

    artist_features = df.groupby('artist_name').agg({
        'popularity': ['mean', 'std', 'count'],
        'acousticness': 'mean',
        'danceability': 'mean',
        'energy': 'mean'
    })
    
    artist_features.columns = [
        'artist_avg_popularity', 'artist_popularity_std', 
        'artist_track_count', 'artist_avg_acousticness',
        'artist_avg_danceability', 'artist_avg_energy'
    ]
    
    for col in artist_features.columns:
        df_features[col] = df_features['artist_name'].map(
            artist_features[col]
        )

    audio_features = [
        'acousticness', 'danceability', 'energy',
        'instrumentalness', 'liveness', 'tempo',
        'loudness', 'speechiness'
    ]
    
    scaler = StandardScaler()
    df_features[audio_features] = scaler.fit_transform(
        df_features[audio_features]
    )
    
    df_features['popularity'] = df_features['popularity'] / 100.0

    df_features['duration_minutes'] = df_features['duration_ms'] / 60000
    
    joblib.dump(scaler, 'audio_features_scaler.joblib')
    
    return df_features, scaler
df_with_features, scaler = create_features(merged_df)

# %%
df_with_features.head()
# Out:
#                  track_id             artist_name                  track_name  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino                      Comedy
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward            Ghost - Acoustic
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN              To Begin Again
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis  Can't Help Falling In Love
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet                     Hold On
#
#                                           album_name  popularity track_genre  \
# 0                                             Comedy        0.73    acoustic
# 1                                   Ghost (Acoustic)        0.55    acoustic
# 2                                     To Begin Again        0.57    acoustic
# 3  Crazy Rich Asians (Original Motion Picture Sou...        0.71    acoustic
# 4                                            Hold On        0.82    acoustic
#
#    duration_ms  acousticness  danceability    energy  ...  liveness     tempo  \
# 0       230666     -0.888859      0.553594 -0.515412  ...  0.857734 -1.080263
# 1       149610      1.711792     -0.829647 -1.645836  ... -0.572910 -1.425929
# 2       210826     -0.370362     -0.732388 -0.906271  ... -0.483843 -1.464281
# 3       201933      1.656385     -1.661753 -2.053555  ... -0.400342  2.029767
# 4       198853      0.384929      0.240203 -0.584387  ... -0.673668 -0.018472
#
#    time_signature  artist_avg_popularity  artist_popularity_std  \
# 0               4              51.571429              10.130106
# 1               4              37.642857               9.344741
# 2               4              57.000000                    NaN
# 3               3              51.370370               8.513104
# 4               4              41.727273              23.937798
#
#    artist_track_count  artist_avg_acousticness  artist_avg_danceability  \
# 0                 7.0                 0.022867                 0.701000
# 1                14.0                 0.676214                 0.627929
# 2                 1.0                 0.210000                 0.438000
# 3                27.0                 0.871333                 0.538593
# 4                11.0                 0.560691                 0.562455
#
#    artist_avg_energy  duration_minutes
# 0           0.611000          3.844433
# 1           0.416571          2.493500
# 2           0.359000          3.513767
# 3           0.154111          3.365550
# 4           0.392818          3.314217
#
# [5 rows x 25 columns]

# %%
df_with_features.isnull().sum()
# Out:
# track_id                        0
# artist_name                     1
# track_name                      2
# album_name                 129900
# popularity                      0
# track_genre                129899
# duration_ms                     0
# acousticness                    0
# danceability                    0
# energy                          0
# key                             0
# loudness                        0
# mode                            0
# speechiness                     0
# instrumentalness                0
# liveness                        0
# tempo                           0
# time_signature                  0
# artist_avg_popularity           1
# artist_popularity_std       37401
# artist_track_count              1
# artist_avg_acousticness         1
# artist_avg_danceability         1
# artist_avg_energy               1
# duration_minutes                0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
def analyze_features(df):
    print("Basic Statistics:")
    print(df.describe())
    
    plt.figure(figsize=(12, 8))
    audio_features = [
        'acousticness', 'danceability', 'energy',
        'instrumentalness', 'liveness', 'tempo',
        'popularity'
    ]
    sns.heatmap(
        df[audio_features].corr(), 
        annot=True, 
        cmap='coolwarm'
    )
    plt.title('Feature Correlations')
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(15, 5))
    for i, feature in enumerate(audio_features[:3], 1):
        plt.subplot(1, 3, i)
        sns.histplot(df[feature], bins=50)
        plt.title(f'{feature} Distribution')
    plt.tight_layout()
    plt.show()

analyze_features(df_with_features)
# Out:
# Basic Statistics:
#           popularity   duration_ms  acousticness  danceability        energy  \
# count  219640.000000  2.196400e+05  2.196400e+05  2.196400e+05  2.196400e+05
# mean        0.277336  2.193819e+05  5.693659e-17 -5.693659e-16  3.245386e-16
# std         0.204546  1.195615e+05  1.000002e+00  1.000002e+00  1.000002e+00
# min         0.000000  0.000000e+00 -9.827602e-01 -3.099026e+00 -2.281939e+00
# 25%         0.110000  1.678525e+05 -9.092724e-01 -6.405321e-01 -6.725220e-01
# 50%         0.260000  2.061065e+05 -4.082723e-01  9.971769e-02  1.360186e-01
# 75%         0.430000  2.504138e+05  8.602671e-01  7.535150e-01  8.181049e-01
# max         1.000000  5.610020e+06  1.921758e+00  2.282644e+00  1.550007e+00
#
#                  key      loudness           mode   speechiness  \
# count  219640.000000  2.196400e+05  219640.000000  2.196400e+05
# mean        5.253984  5.590138e-17       0.619796  2.691548e-17
# std         3.585898  1.000002e+00       0.485438  1.000002e+00
# min         0.000000 -8.308551e+00       0.000000 -8.459403e-01
# 25%         2.000000 -3.064901e-01       0.000000 -5.343379e-01
# 50%         5.000000  2.860849e-01       1.000000 -4.100285e-01
# 75%         8.000000  6.473751e-01       1.000000  4.080048e-02
# max        11.000000  2.284261e+00       1.000000  7.159589e+00
#
#        instrumentalness      liveness         tempo  time_signature  \
# count      2.196400e+05  2.196400e+05  2.196400e+05   219640.000000
# mean      -1.407887e-16 -1.462235e-16  4.749029e-16        3.886255
# std        1.000002e+00  1.000002e+00  1.000002e+00        0.491179
# min       -5.871456e-01 -1.135148e+00 -3.994522e+00        0.000000
# 25%       -5.871456e-01 -5.912803e-01 -7.714331e-01        4.000000
# 50%       -5.868621e-01 -4.281758e-01  2.735710e-04        4.000000
# 75%        1.907679e-01  2.787962e-01  6.447174e-01        4.000000
# max        2.294016e+00  4.431560e+00  4.291875e+00        5.000000
#
#        artist_avg_popularity  artist_popularity_std  artist_track_count  \
# count          219639.000000          182239.000000       219639.000000
# mean               27.733740               8.971749          106.809906
# std                17.830507               7.654675          497.297908
# min                 0.000000               0.000000            1.000000
# 25%                13.711538               3.438591            2.000000
# 50%                26.250000               7.406277           10.000000
# 75%                41.000000              12.275993           24.000000
# max               100.000000              57.982756         3635.000000
#
#        artist_avg_acousticness  artist_avg_danceability  artist_avg_energy  \
# count            219639.000000            219639.000000      219639.000000
# mean                  0.337001                 0.573545           0.595504
# std                   0.300808                 0.158286           0.230639
# min                   0.000000                 0.000000           0.000000
# 25%                   0.082735                 0.476375           0.461000
# 50%                   0.246298                 0.590000           0.629437
# 75%                   0.539000                 0.690288           0.766000
# max                   0.996000                 0.981000           1.000000
#
#        duration_minutes
# count     219640.000000
# mean           3.656365
# std            1.992691
# min            0.000000
# 25%            2.797542
# 50%            3.435108
# 75%            4.173563
# max           93.500333

# %%
df_with_features['artist_name'] = df_with_features['artist_name'].fillna("unknown_artist")
df_with_features['track_name'] = df_with_features['track_name'].fillna("unknown_track")
df_with_features['album_name'] = df_with_features['album_name'].fillna("unknown_album")
df_with_features['track_genre'] = df_with_features['track_genre'].fillna("unknown_genre")
df_with_features['artist_avg_popularity'] = df_with_features['artist_avg_popularity'].fillna(0)
df_with_features['artist_popularity_std'] = df_with_features['artist_popularity_std'].fillna(0)
df_with_features['artist_track_count'] = df_with_features['artist_track_count'].fillna(0)
df_with_features['artist_avg_danceability'] = df_with_features['artist_avg_danceability'].fillna(0)
df_with_features['artist_avg_energy'] = df_with_features['artist_avg_energy'].fillna(0)
df_with_features['artist_avg_acousticness'] = df_with_features['artist_avg_acousticness'].fillna(0)

# %%
df_with_features.isnull().sum()
# Out:
# track_id                   0
# artist_name                0
# track_name                 0
# album_name                 0
# popularity                 0
# track_genre                0
# duration_ms                0
# acousticness               0
# danceability               0
# energy                     0
# key                        0
# loudness                   0
# mode                       0
# speechiness                0
# instrumentalness           0
# liveness                   0
# tempo                      0
# time_signature             0
# artist_avg_popularity      0
# artist_popularity_std      0
# artist_track_count         0
# artist_avg_acousticness    0
# artist_avg_danceability    0
# artist_avg_energy          0
# duration_minutes           0
# dtype: int64

# %%
# Use hopsworks as feature store
# !pip install "hopsworks[python]"
# Out:
# Requirement already satisfied: hopsworks[python] in g:\alok\recommender_system\rs_env\lib\site-packages (4.1.8)
# Requirement already satisfied: pyhumps==1.6.1 in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (1.6.1)
# Requirement already satisfied: requests in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (2.32.3)
# Requirement already satisfied: furl in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (2.1.3)
# Requirement already satisfied: boto3 in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (1.36.16)
# Requirement already satisfied: pandas<2.2.0 in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (2.1.4)
# Requirement already satisfied: pyjks in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (20.0.0)
# Requirement already satisfied: mock in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (5.1.0)
# Requirement already satisfied: avro==1.11.3 in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (1.11.3)
# Requirement already satisfied: sqlalchemy in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (2.0.29)
# Requirement already satisfied: PyMySQL[rsa] in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (1.1.1)
# Requirement already satisfied: tzlocal in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (5.2)
# Requirement already satisfied: fsspec in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (2025.2.0)
# Requirement already satisfied: retrying in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (1.3.4)
# Requirement already satisfied: hopsworks_aiomysql==0.2.1 in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks_aiomysql[sa]==0.2.1->hopsworks[python]) (0.2.1)
# Requirement already satisfied: opensearch-py<=2.4.2,>=1.1.0 in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (2.4.2)
# Requirement already satisfied: tqdm in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (4.67.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.49.1 in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (1.70.0)
# Requirement already satisfied: protobuf<5.0.0,>=4.25.4 in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (4.25.6)
# Requirement already satisfied: packaging in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (24.2)
# Requirement already satisfied: numpy<2 in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (1.26.4)
# Requirement already satisfied: pyarrow>=10.0 in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (19.0.0)
# Requirement already satisfied: confluent-kafka<=2.3.0 in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (2.3.0)
# Requirement already satisfied: fastavro<=1.8.4,>=1.4.11 in g:\alok\recommender_system\rs_env\lib\site-packages (from hopsworks[python]) (1.8.4)
# Requirement already satisfied: urllib3>=1.26.18 in g:\alok\recommender_system\rs_env\lib\site-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks[python]) (2.3.0)
# Requirement already satisfied: six in g:\alok\recommender_system\rs_env\lib\site-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks[python]) (1.17.0)
# Requirement already satisfied: python-dateutil in g:\alok\recommender_system\rs_env\lib\site-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks[python]) (2.9.0.post0)
# Requirement already satisfied: certifi>=2022.12.07 in g:\alok\recommender_system\rs_env\lib\site-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks[python]) (2025.1.31)
# Requirement already satisfied: pytz>=2020.1 in g:\alok\recommender_system\rs_env\lib\site-packages (from pandas<2.2.0->hopsworks[python]) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in g:\alok\recommender_system\rs_env\lib\site-packages (from pandas<2.2.0->hopsworks[python]) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in g:\alok\recommender_system\rs_env\lib\site-packages (from requests->hopsworks[python]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in g:\alok\recommender_system\rs_env\lib\site-packages (from requests->hopsworks[python]) (3.10)
# Requirement already satisfied: typing-extensions>=4.6.0 in g:\alok\recommender_system\rs_env\lib\site-packages (from sqlalchemy->hopsworks[python]) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in g:\alok\recommender_system\rs_env\lib\site-packages (from sqlalchemy->hopsworks[python]) (3.1.1)
# Requirement already satisfied: botocore<1.37.0,>=1.36.16 in g:\alok\recommender_system\rs_env\lib\site-packages (from boto3->hopsworks[python]) (1.36.16)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in g:\alok\recommender_system\rs_env\lib\site-packages (from boto3->hopsworks[python]) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in g:\alok\recommender_system\rs_env\lib\site-packages (from boto3->hopsworks[python]) (0.11.2)
# Requirement already satisfied: orderedmultidict>=1.0.1 in g:\alok\recommender_system\rs_env\lib\site-packages (from furl->hopsworks[python]) (1.0.1)
# Requirement already satisfied: javaobj-py3 in g:\alok\recommender_system\rs_env\lib\site-packages (from pyjks->hopsworks[python]) (0.4.4)
# Requirement already satisfied: pyasn1>=0.3.5 in g:\alok\recommender_system\rs_env\lib\site-packages (from pyjks->hopsworks[python]) (0.6.1)
# Requirement already satisfied: pyasn1-modules in g:\alok\recommender_system\rs_env\lib\site-packages (from pyjks->hopsworks[python]) (0.4.1)
# Requirement already satisfied: pycryptodomex in g:\alok\recommender_system\rs_env\lib\site-packages (from pyjks->hopsworks[python]) (3.21.0)
# Requirement already satisfied: twofish in g:\alok\recommender_system\rs_env\lib\site-packages (from pyjks->hopsworks[python]) (0.3.0)
# Requirement already satisfied: cryptography in g:\alok\recommender_system\rs_env\lib\site-packages (from PyMySQL[rsa]->hopsworks[python]) (44.0.0)
# Requirement already satisfied: colorama in g:\alok\recommender_system\rs_env\lib\site-packages (from tqdm->hopsworks[python]) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in g:\alok\recommender_system\rs_env\lib\site-packages (from cryptography->PyMySQL[rsa]->hopsworks[python]) (1.17.1)
# Requirement already satisfied: pycparser in g:\alok\recommender_system\rs_env\lib\site-packages (from cffi>=1.12->cryptography->PyMySQL[rsa]->hopsworks[python]) (2.22)

# %%
import pyarrow

# %%
import hopsworks
project = hopsworks.login()
# Out:
# 2025-02-09 14:48:09,884 INFO: Initializing external client
# 2025-02-09 14:48:09,886 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-02-09 14:48:14,632 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1213608

# %%
feature_store = project.get_feature_store()
recommender = feature_store.get_or_create_feature_group(
    name="recommender_spotify",
    description="Spotify features for recommendation system",
    version=2,
    primary_key=["track_id"], 
    event_time=None     
)

# %%
recommender.insert(df_with_features)
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1213608/fs/1201238/fg/1398770
# Uploading Dataframe: 100.00% |███████████████████████| Rows 219640/219640 | Elapsed Time: 00:27 | Remaining Time: 00:00
# Launching job: recommender_spotify_2_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1213608/jobs/named/recommender_spotify_2_offline_fg_materialization/executions
# (Job('recommender_spotify_2_offline_fg_materialization', 'SPARK'), None)

# %%
feature_descriptions = {
    "track_id": "Unique ID of the track, used as the primary key.",
    "artist_name": "Name of the artist associated with the track.",
    "track_name": "Name of the track. If unknown, replaced with 'unknown_track'.",
    "album_name": "Album where the track is included. If unknown, replaced with 'unknown_album'.",
    "popularity": "Normalized popularity of the track, scaled to a range of 0.0 to 1.0.",
    "duration_ms": "Duration of the track in milliseconds.",
    "duration_minutes": "Duration of the track, converted from milliseconds to minutes.",
    "acousticness": "Standardized acousticness of the track (normalized).",
    "danceability": "Standardized danceability of the track (normalized).",
    "energy": "Standardized energy level of the track (normalized).",
    "liveness": "Standardized liveness of the track, indicating presence of an audience (normalized).",
    "tempo": "Standardized tempo of the track, representing beats per minute (normalized).",
    "time_signature": "The time signature of the track, expressed as beats per bar.",
    "artist_avg_popularity": "Average popularity of the artist across all tracks, calculated from the dataset.",
    "artist_popularity_std": "Standard deviation of the artist's track popularity, representing popularity variability.",
    "artist_track_count": "Total number of tracks associated with the artist in the dataset.",
    "artist_avg_acousticness": "Average acousticness across all tracks by the artist.",
    "artist_avg_danceability": "Average danceability across all tracks by the artist.",
    "artist_avg_energy": "Average energy across all tracks by the artist."
}

for feature, description in feature_descriptions.items():
    recommender.update_feature_description(feature, description)

print("Spotify features successfully updated in Hopsworks Feature Store!")
# Out:
# Spotify features successfully updated in Hopsworks Feature Store!

# %%
fg = feature_store.get_feature_group('recommender_spotify', version=2)

# %%
test_df = fg.read()
test_df.head()
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (7.07s)
#                  track_id        artist_name  \
# 0  1wdjBrN3XqdXHcM0HTtncu   Cumbias Clasicas
# 1  1JGW1e2tacnCgBPfRH0haY        Snowy White
# 2  37gMuz8yU3nuL6F49ywDDv      Akira The Don
# 3  7fumRmsJgKUj0Zl8OaRJlW       Joe Satriani
# 4  0E2Tf1I1vrjbkE8sjB17Uh  Dj Wesley Gonzaga
#
#                                          track_name  \
# 0                                         Nube Gris
# 1                                  Bird of Paradise
# 2  Pursue What Is Meaningful, Not What Is Expedient
# 3                                         Ten Words
# 4    Mtg - Antes de Me Conhecer, Até Neymar de Cara
#
#                                        album_name  popularity    track_genre  \
# 0                                   unknown_album        0.01  unknown_genre
# 1                 Bird of Paradise - An Anthology        0.55        british
# 2                                   unknown_album        0.30  unknown_genre
# 3                                  Super Colossal        0.37         guitar
# 4  Mtg - Antes de Me Conhecer, Até Neymar de Cara        0.42           funk
#
#    duration_ms  acousticness  danceability    energy  ...  liveness     tempo  \
# 0       173800     -0.265379      0.996663 -0.358302  ... -0.955343 -0.468785
# 1       281466      0.766949     -0.537870 -0.584387  ...  0.623932  0.766967
# 2       282000     -0.151648     -0.305529  0.695483  ... -0.016239  0.990317
# 3       208586     -0.954998     -1.445621  0.078539  ...  0.028294  1.959659
# 4       156461      1.087729      0.321252  0.174338  ... -0.355809 -1.216600
#
#    time_signature  artist_avg_popularity  artist_popularity_std  \
# 0               4               1.000000               0.794719
# 1               4              57.500000               3.535534
# 2               4              29.750000               2.958040
# 3               4              40.692308               6.342045
# 4               3              42.000000               0.000000
#
#    artist_track_count  artist_avg_acousticness  artist_avg_danceability  \
# 0                20.0                 0.200240                 0.777000
# 1                 2.0                 0.705000                 0.510500
# 2                12.0                 0.132429                 0.580750
# 3                26.0                 0.049793                 0.511038
# 4                 1.0                 0.710000                 0.633000
#
#    artist_avg_energy  duration_minutes
# 0           0.504850          2.896667
# 1           0.308500          4.691100
# 2           0.730333          4.700000
# 3           0.757192          3.476433
# 4           0.641000          2.607683
#
# [5 rows x 25 columns]
